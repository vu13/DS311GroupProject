# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
states=pd.read_csv("salary_data_states.csv")

# %%
coaststatus = []
# Only west coast and east coast
coastalstates = ['California', 'Oregon', 'Washington', 'Florida', 'Georgia','South Carolina', 'North Carolina', 
                 'Virginia', 'District of Columbia', 'Maryland', 'Delaware', 'New Jersey','New York', 'Connecticut', 
                 'Rhode Island', 'Massachusetts', 'New Hamsphire', 'Maine', 'Pennsylvania']
for num in states['WORK_STATE']:
    if num in coastalstates:
       coaststatus.append('E/W coast')
    else:
        coaststatus.append('Non-E/W coast')
print('East and West coastal states applicant counts:', len(coastal), 
      'Non-east and west coast states applicantion counts:', len(landlock), sep='\n')
# Out:
# East and West coastal states applicant counts:
# 114496
# Non-east and west coast states applicantion counts:
# 52781

# %%
states['Coast_Status'] = coaststatus
states
# Out:
#         Unnamed: 0         CASE_NUMBER          CASE_STATUS  \
# 0                0  I-200-14073-248840               denied
# 1                1       A-15061-55212               denied
# 2                2  I-200-13256-001092               denied
# 3                3  I-200-14087-353657               denied
# 4                4  I-203-14259-128844               denied
# ...            ...                 ...                  ...
# 167272      167273  I-200-12241-209885  certified-withdrawn
# 167273      167274  I-200-11305-143547               denied
# 167274      167275  I-200-11313-833007            certified
# 167275      167276  I-200-11312-798611               denied
# 167276      167277  I-200-11297-523711               denied
#
#        CASE_RECEIVED_DATE DECISION_DATE  \
# 0               3/14/2014     3/21/2014
# 1               3/19/2015     3/19/2015
# 2               9/13/2013     9/23/2013
# 3               3/28/2014      4/7/2014
# ...

# %%
coastnum = states['Coast_Status'].value_counts()
fig, ax = plt.subplots(figsize=(8,4))
plt.bar(coastnum.index, coastnum.values)
ax.set_ylabel('Application Counts')
# Out:
# Text(0, 0.5, 'Application Counts')

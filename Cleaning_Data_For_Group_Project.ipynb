# %%
import pandas as pd
pd = pd.DataFrame(pd.read_excel("salary_data_states_corrected.xlsx"))
pd
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
pd1 = pd.copy()
pd1.dropna(axis = 1)
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
pd2 = pd.copy()
sorted(pd2)
# Out:
# ['CASE_NUMBER',
#  'CASE_RECEIVED_DATE',
#  'CASE_STATUS',
#  'COLLEGE_MAJOR_REQUIRED',
#  'COUNTRY_OF_CITIZENSHIP',
#  'DECISION_DATE',
#  'EDUCATION_LEVEL_REQUIRED',
#  'EMPLOYER_NAME',
#  'EXPERIENCE_REQUIRED_NUM_MONTHS',
#  'EXPERIENCE_REQUIRED_Y_N',
#  'FULL_TIME_POSITION_Y_N',
#  'JOB_TITLE',
#  'JOB_TITLE_SUBGROUP',
#  'PAID_WAGE_PER_YEAR',
#  'PAID_WAGE_SUBMITTED',
#  'PAID_WAGE_SUBMITTED_UNIT',
#  'PREVAILING_WAGE_PER_YEAR',
#  'PREVAILING_WAGE_SOC_CODE',
#  'PREVAILING_WAGE_SOC_TITLE',
#  'PREVAILING_WAGE_SUBMITTED',
#  'PREVAILING_WAGE_SUBMITTED_UNIT',
#  'VISA_CLASS',
#  'WORK_CITY',
#  'WORK_POSTAL_CODE',
#  'WORK_STATE',
#  'WORK_STATE_ABBREVIATION',
#  'order']

# %%
pd2.isna().sum()
# Out:
# CASE_NUMBER                            0
# CASE_STATUS                            0
# CASE_RECEIVED_DATE                     0
# DECISION_DATE                          0
# EMPLOYER_NAME                          0
# PREVAILING_WAGE_SUBMITTED              0
# PREVAILING_WAGE_SUBMITTED_UNIT         0
# PAID_WAGE_SUBMITTED                    0
# PAID_WAGE_SUBMITTED_UNIT               0
# JOB_TITLE                              0
# WORK_CITY                              3
# EDUCATION_LEVEL_REQUIRED          156185
# COLLEGE_MAJOR_REQUIRED            156227
# EXPERIENCE_REQUIRED_Y_N           156185
# EXPERIENCE_REQUIRED_NUM_MONTHS    162313
# COUNTRY_OF_CITIZENSHIP            156185
# PREVAILING_WAGE_SOC_CODE               0
# PREVAILING_WAGE_SOC_TITLE              0
# WORK_STATE                             0
# WORK_STATE_ABBREVIATION                0
# WORK_POSTAL_CODE                  113604
# FULL_TIME_POSITION_Y_N             11093
# VISA_CLASS                             0
# ...

# %%
pd2.drop(["EDUCATION_LEVEL_REQUIRED", "COLLEGE_MAJOR_REQUIRED", "EXPERIENCE_REQUIRED_Y_N", 
                    "EXPERIENCE_REQUIRED_NUM_MONTHS", "COUNTRY_OF_CITIZENSHIP", "WORK_POSTAL_CODE"], 
                       axis = 1, inplace = True)
sorted(pd2)
# Out:
# ['CASE_NUMBER',
#  'CASE_RECEIVED_DATE',
#  'CASE_STATUS',
#  'DECISION_DATE',
#  'EMPLOYER_NAME',
#  'FULL_TIME_POSITION_Y_N',
#  'JOB_TITLE',
#  'JOB_TITLE_SUBGROUP',
#  'PAID_WAGE_PER_YEAR',
#  'PAID_WAGE_SUBMITTED',
#  'PAID_WAGE_SUBMITTED_UNIT',
#  'PREVAILING_WAGE_PER_YEAR',
#  'PREVAILING_WAGE_SOC_CODE',
#  'PREVAILING_WAGE_SOC_TITLE',
#  'PREVAILING_WAGE_SUBMITTED',
#  'PREVAILING_WAGE_SUBMITTED_UNIT',
#  'VISA_CLASS',
#  'WORK_CITY',
#  'WORK_STATE',
#  'WORK_STATE_ABBREVIATION',
#  'order']

# %%
pd2
# Out:
#                CASE_NUMBER          CASE_STATUS CASE_RECEIVED_DATE  \
# 0       I-200-14073-248840               denied          3/14/2014
# 1            A-15061-55212               denied          3/19/2015
# 2       I-200-13256-001092               denied          9/13/2013
# 3       I-200-14087-353657               denied          3/28/2014
# 4       I-203-14259-128844               denied          9/16/2014
# ...                    ...                  ...                ...
# 167273  I-200-12241-209885  certified-withdrawn          8/28/2012
# 167274  I-200-11305-143547               denied          11/1/2011
# 167275  I-200-11313-833007            certified          11/9/2011
# 167276  I-200-11312-798611               denied          11/8/2011
# 167277  I-200-11297-523711               denied         10/24/2011
#
#        DECISION_DATE                                      EMPLOYER_NAME  \
# 0          3/21/2014                ADVANCED TECHNOLOGY GROUP USA, INC.
# ...

# %%
pd2.to_csv("salary_data_states.csv")
